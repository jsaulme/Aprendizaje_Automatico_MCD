# %% [markdown]
# <a href="https://colab.research.google.com/github/jsaulme/Aprendizaje_Automatico_MCD/blob/main/fifa_worldcup2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from string import ascii_uppercase as alfabeto
import pickle

# %%
data = "https://web.archive.org/web/20221114220634/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup"

# %%
#data2026 = "https://web.archive.org/web/20221114220634/https://en.wikipedia.org/wiki/2026_FIFA_World_Cup"

# %%
alfabeto
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
for letra, i in zip(alfabeto, range(12, 83, 7)):
    print(letra, i)
# Out:
# A 12
# B 19
# C 26
# D 33
# E 40
# F 47
# G 54
# H 61
# I 68
# J 75
# K 82

# %%
# Grupo A -> H
#data[12]
#data[19]
#data[26]
#data[33]
#data[40]
#data[47]
#data[54]
data[61]
# Out:
#    Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1     Portugal    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2        Ghana    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3      Uruguay    0  0  0  0   0   0   0    0                        NaN
# 3    4  South Korea    0  0  0  0   0   0   0    0                        NaN

# %%
for i in range(12, 62, 7):
    print(data[i].columns[1])
# Out:
# Teamvte
# Teamvte
# Teamvte
# Teamvte
# Teamvte
# Teamvte
# Teamvte
# Teamvte

# %%
# Renombrar todas las columnas 1 por el nombre "Team" y elimina la columna "Qualification"

dict_grupos = {}
for letra, i in zip(alfabeto, range(12, 62, 7)):
    df = data[i]
    df.rename(columns={df.columns[1]: 'Team'}, inplace=True)
    df.pop('Qualification')
    dict_grupos[f'Grupo {letra}'] = df

# %%
dict_grupos.keys()
# Out:
# dict_keys(['Grupo A', 'Grupo B', 'Grupo C', 'Grupo D', 'Grupo E', 'Grupo F', 'Grupo G', 'Grupo H'])

# %%
dict_grupos['Grupo A']
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1    Qatar (H)    0  0  0  0   0   0   0    0
# 1    2      Ecuador    0  0  0  0   0   0   0    0
# 2    3      Senegal    0  0  0  0   0   0   0    0
# 3    4  Netherlands    0  0  0  0   0   0   0    0

# %%
with open('dict_grupos', 'wb') as output:
    pickle.dump(dict_grupos, output)

# %%
# Ver archivos del entorno
# !ls
# Out:
# all_world_cup_matches.csv	     fifa_mundiales_data.csv
# clean_all_fifa_worldcup_matches.csv  fifa_mundiales_data_fix.csv
# clean_fifa_mundiales_data_fix.csv    google-chrome-stable_current_amd64.deb
# dict_grupos			     sample_data

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Set "years" que vaya desde 1930 a 2022 (incluido), de 4 en 4

years = set(range(1930, 2027, 4))
print(years)
# Out:
# {1930, 1934, 1938, 1942, 1946, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018, 2022, 2026}

# %%
# Funcion para obtener los partidos por año
def get_partidos(year):

  web = f"https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup"
  response = requests.get(web)
  content = response.text
  soup = BeautifulSoup(content, 'lxml')
  partidos = soup.find_all("div", class_="footballbox")

  home = []
  score = []
  away = []

  for partido in partidos:
    home.append(partido.find("th", class_="fhome").get_text())
    score.append(partido.find("th", class_="fscore").get_text())
    away.append(partido.find("th", class_="faway").get_text())

  dict_partidos = {'Home': home, 'Score': score, 'Away': away}
  df_partidos = pd.DataFrame(dict_partidos)
  df_partidos["Year"] = year
  return df_partidos

# %%
print(get_partidos(2026))
# Out:
#                  Home      Score              Away  Year
# 0             Mexico     Match 1                A2  2026
# 1                  A3    Match 2                A4  2026
# 2                  A4   Match 25                A2  2026
# 3             Mexico    Match 28                A3  2026
# 4                  A4   Match 53            Mexico  2026
# ..                ...        ...               ...   ...
# 99    Winner Match 95  Match 100   Winner Match 96  2026
# 100   Winner Match 97  Match 101   Winner Match 98  2026
# 101   Winner Match 99  Match 102  Winner Match 100  2026
# 102   Loser Match 101  Match 103   Loser Match 102  2026
# 103  Winner Match 101  Match 104  Winner Match 102  2026
#
# [104 rows x 4 columns]

# %%
mundiales = [get_partidos(year) for year in years]
df_mundiales = pd.concat(mundiales, ignore_index=True)
df_mundiales.to_csv("fifa_mundiales_data.csv", index=False)

# %%
df_fix = get_partidos(2022)
df_fix.to_csv("fifa_mundiales_data_fix.csv", index=False)

# %%
# !ls
# Out:
# all_world_cup_matches.csv	     fifa_mundiales_data.csv
# clean_all_fifa_worldcup_matches.csv  fifa_mundiales_data_fix.csv
# clean_fifa_mundiales_data_fix.csv    google-chrome-stable_current_amd64.deb
# dict_grupos			     sample_data

# %%
# !google-chrome --version
# Out:
# Google Chrome 127.0.6533.99

# %%
# @title
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !apt-get install -y ./google-chrome-stable_current_amd64.deb
# Out:
# --2024-08-09 21:54:17--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 172.217.164.14, 2607:f8b0:4025:810::200e
# Connecting to dl.google.com (dl.google.com)|172.217.164.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109464716 (104M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb.1’
#
# google-chrome-stabl 100%[===================>] 104.39M  20.2MB/s    in 5.3s
#
# 2024-08-09 21:54:22 (19.8 MB/s) - ‘google-chrome-stable_current_amd64.deb.1’ saved [109464716/109464716]
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'google-chrome-stable' instead of './google-chrome-stable_current_amd64.deb'
# google-chrome-stable is already the newest version (127.0.6533.99-1).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.

# %%
# !pip install selenium webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)
driver.get('https://www.google.com')
print(driver.title)
#driver.quit()
# Out:
# Google

# %%
web = ("https://en.wikipedia.org/wiki/1982_FIFA_World_Cup")
driver.get(web)

# %%
# Comprueba que el driver.get(web) funcioona correctamente
print(driver.title)
# Out:
# 1982 FIFA World Cup - Wikipedia

# %%
element_italy = driver.find_element(by="xpath", value='//th[@class="fhome"]/span[@itemprop="name"]/a')
home_team = element_italy.text
print(home_team)  # Debería imprimir "Italy"
# Out:
# Italy

# %%
element_score = driver.find_element(by="xpath", value='//th[@class="fscore"]')
score = element_score.text
print(score)  # Debería imprimir "0-0"
# Out:
# 0–0

# %%
# Extraer "Poland"
element_poland = driver.find_element(by="xpath", value='//th[@class="faway"]//span[@itemprop="name"]//a')
away_team = element_poland.text
print(away_team)  # Debería imprimir "Poland"
# Out:
# Poland

# %% [markdown]
# #Ya has encontrado el codigo correcto para extraer los elementos de visitante, marcador y equipo local.
#
# Sigue viendo:
# https://www.youtube.com/watch?v=EuZ4gwNNYwg
#
# Minuto: 01:15

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Función para obtener los partidos por año
def get_partidos_faltantes(year):
    web = f"https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup"
    response = requests.get(web)
    content = response.text
    soup = BeautifulSoup(content, 'lxml')

    # Encontrar todos los partidos
    partidos = soup.find_all("div", class_="footballbox")

    home = []
    score = []
    away = []

    for partido in partidos:
        # Extraer equipo local
        home_team = partido.find("th", class_="fhome").get_text().strip()
        home.append(home_team)

        # Extraer resultado
        match_score = partido.find("th", class_="fscore").get_text().strip()
        score.append(match_score)

        # Extraer equipo visitante
        away_team = partido.find("th", class_="faway").get_text().strip()
        away.append(away_team)

    # Crear un diccionario con los resultados
    dict_partidos = {'Home': home, 'Score': score, 'Away': away}
    df_partidos = pd.DataFrame(dict_partidos)
    df_partidos["Year"] = year
    return df_partidos

# Usar la función para obtener los partidos de 1982
df_partidos_1982 = get_partidos(1982)
print(df_partidos_1982)
# Out:
#                Home         Score               Away  Year
# 0            Italy            0–0             Poland  1982
# 1             Peru            0–0           Cameroon  1982
# 2            Italy            1–1               Peru  1982
# 3           Poland            0–0           Cameroon  1982
# 4           Poland            5–1               Peru  1982
# 5            Italy            1–1           Cameroon  1982
# 6     West Germany            1–2            Algeria  1982
# 7            Chile            0–1            Austria  1982
# 8     West Germany            4–1              Chile  1982
# 9          Algeria            0–2            Austria  1982
# 10         Algeria            3–2              Chile  1982
# 11    West Germany            1–0            Austria  1982
# 12       Argentina            0–1            Belgium  1982
# 13         Hungary           10–1        El Salvador  1982
# 14       Argentina            4–1            Hungary  1982
# ...

# %%
# Función para obtener los partidos por año
def get_partidos(year):
    web = f"https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup"
    response = requests.get(web)
    content = response.text
    soup = BeautifulSoup(content, 'lxml')

    # Encontrar todos los partidos
    partidos = soup.find_all("div", class_="footballbox")

    home = []
    score = []
    away = []

    for partido in partidos:
        # Extraer equipo local
        home_team = partido.find("th", class_="fhome").get_text().strip()
        home.append(home_team)

        # Extraer resultado
        match_score = partido.find("th", class_="fscore").get_text().strip()
        score.append(match_score)

        # Extraer equipo visitante
        away_team = partido.find("th", class_="faway").get_text().strip()
        away.append(away_team)

    # Crear un diccionario con los resultados
    dict_partidos = {'Home': home, 'Score': score, 'Away': away}
    df_partidos = pd.DataFrame(dict_partidos)
    df_partidos["Year"] = year
    return df_partidos

# Conjunto de años para los que queremos extraer los datos
years = {1930, 1934, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982,
         1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018, 2022}

# Lista para almacenar los DataFrames de cada año
all_partidos = []

# Iterar sobre cada año y obtener los partidos
for year in years:
    df_partidos = get_partidos(year)
    all_partidos.append(df_partidos)

# Concatenar todos los DataFrames en uno solo
df_all_partidos = pd.concat(all_partidos, ignore_index=True)

# Mostrar el DataFrame final con todos los partidos
print(df_all_partidos)
# Out:
#              Home         Score              Away  Year
# 0        Bulgaria           1–1             Italy  1986
# 1       Argentina           3–1       South Korea  1986
# 2           Italy           1–1         Argentina  1986
# 3     South Korea           1–1          Bulgaria  1986
# 4     South Korea           2–3             Italy  1986
# ..            ...           ...               ...   ...
# 923        France           4–1  Northern Ireland  1982
# 924        Poland           0–2             Italy  1982
# 925  West Germany  3–3 (a.e.t.)            France  1982
# 926        Poland           3–2            France  1982
# 927         Italy           3–1      West Germany  1982
#
# [928 rows x 4 columns]

# %%
# Exporta el DataFrame a un archivo CSV
df_all_partidos.to_csv("all_world_cup_matches.csv", index=False)

# %%
# !ls
# Out:
# all_world_cup_matches.csv	     fifa_mundiales_data_fix.csv
# clean_all_fifa_worldcup_matches.csv  google-chrome-stable_current_amd64.deb
# clean_fifa_mundiales_data_fix.csv    google-chrome-stable_current_amd64.deb.1
# dict_grupos			     sample_data
# fifa_mundiales_data.csv

# %%
# Para evitar conflictos con nombres ya declarados, usa un nombre diferente para el DataFrame
df_all_matches = pd.read_csv("all_world_cup_matches.csv")
df_fifa_mundiales = pd.read_csv("fifa_mundiales_data.csv")
df_fifa_mundiales_fix = pd.read_csv("fifa_mundiales_data_fix.csv")

# Ahora puedes trabajar con el DataFrame usando df_all_matches
df_all_matches.sort_values(by="Year", inplace=True)
#df_all_matches.reset_index(inplace=True, drop=True)
df_fifa_mundiales
# Out:
#            Home         Score      Away  Year
# 0       France            4–1    Mexico  1930
# 1    Argentina            1–0    France  1930
# 2        Chile            3–0    Mexico  1930
# 3        Chile            1–0    France  1930
# 4    Argentina            6–3    Mexico  1930
# ..          ...           ...       ...   ...
# 923    England            1–2    France  2022
# 924  Argentina            3–0   Croatia  2022
# 925     France            2–0   Morocco  2022
# 926    Croatia            2–1   Morocco  2022
# 927  Argentina   3–3 (a.e.t.)    France  2022
#
# [928 rows x 4 columns]

# %%
# Muestra la columna "Home" del df_fifa_mundiales
df_fifa_mundiales_fix["Home"] = df_fifa_mundiales_fix["Home"].str.strip()
df_fifa_mundiales_fix["Away"] = df_fifa_mundiales_fix["Away"].str.strip()
df_fifa_mundiales["Home"] = df_fifa_mundiales["Home"].str.strip()
df_fifa_mundiales["Away"] = df_fifa_mundiales["Away"].str.strip()
df_all_matches["Home"] = df_all_matches["Home"].str.strip()
df_all_matches["Away"] = df_all_matches["Away"].str.strip()

# %%
# Muestra los valores vacios de la columna "Home" del df_all_matches
df_fifa_mundiales_fix.isnull().sum()
# Out:
# Home     54
# Score     0
# Away     54
# Year      0
# dtype: int64

# %%
df_all_matches = pd.concat([df_fifa_mundiales, df_all_matches], ignore_index=True)
df_all_matches
# Out:
#             Home Score       Away  Year
# 0         France   4–1     Mexico  1930
# 1      Argentina   1–0     France  1930
# 2          Chile   3–0     Mexico  1930
# 3          Chile   1–0     France  1930
# 4      Argentina   6–3     Mexico  1930
# ...          ...   ...        ...   ...
# 1851       Spain   1–1    Germany  2022
# 1852       Japan   2–1      Spain  2022
# 1853  Costa Rica   2–4    Germany  2022
# 1854      Poland   0–2  Argentina  2022
# 1855     Ecuador   1–2    Senegal  2022
#
# [1856 rows x 4 columns]

# %%
df_all_matches.drop_duplicates(inplace=True)
df_all_matches.sort_values(by="Year", inplace=True)
df_all_matches.reset_index(inplace=True, drop=True)
df_all_matches
# Out:
#           Home         Score           Away  Year
# 0       France           4–1         Mexico  1930
# 1      Uruguay           4–2      Argentina  1930
# 2      Uruguay           6–1     Yugoslavia  1930
# 3    Argentina           6–1  United States  1930
# 4     Paraguay           1–0        Belgium  1930
# ..         ...           ...            ...   ...
# 923      Japan           0–1     Costa Rica  2022
# 924      Spain           1–1        Germany  2022
# 925      Japan           2–1          Spain  2022
# 926    Morocco           0–0        Croatia  2022
# 927  Argentina  3–3 (a.e.t.)         France  2022
#
# [928 rows x 4 columns]

# %%
# Filtra el df_all_matches en donde "score" contenga mas de 3 caracteres
df_all_matches[df_all_matches['Score'].str.len() > 3].count()
# Out:
# Home     74
# Score    74
# Away     74
# Year     74
# dtype: int64

# %%
df_all_matches[df_all_matches["Home"].str.contains("Sweden") & df_all_matches["Away"].str.contains("Austria")]
# Out:
#       Home Score     Away  Year
# 49  Sweden   w/o  Austria  1938

# %%
# Filtrar resultados que no sigan el patrón numérico 'X–Y'
df_all_matches[~df_all_matches['Score'].str.match(r'^\d+–\d+$')]
# Out:
#                Home         Score            Away  Year
# 17            Italy  1–1 (a.e.t.)           Spain  1934
# 18            Italy  2–1 (a.e.t.)  Czechoslovakia  1934
# 26          Austria  3–2 (a.e.t.)          France  1934
# 36           Brazil  1–1 (a.e.t.)  Czechoslovakia  1938
# 44   Czechoslovakia  3–0 (a.e.t.)     Netherlands  1938
# ..              ...           ...             ...   ...
# 883           Japan  1–1 (a.e.t.)         Croatia  2022
# 885         Morocco  0–0 (a.e.t.)           Spain  2022
# 887         Croatia  1–1 (a.e.t.)          Brazil  2022
# 888     Netherlands  2–2 (a.e.t.)       Argentina  2022
# 927       Argentina  3–3 (a.e.t.)          France  2022
#
# [74 rows x 4 columns]

# %%
# Filtrar marcadores que contengan letras, pero excluir aquellos que contienen "(a.e.t.)"
df_all_matches[
    df_all_matches['Score'].str.contains('[a-zA-Z]') &
    ~df_all_matches['Score'].str.contains(r'\(a\.e\.t\.\)')
]
df_all_matches['Score'] = df_all_matches['Score'].str.replace(r'\(a\.e\.t\.\)', '', regex=True) # Replace '(a.e.t.)' with an empty string
df_all_matches
# Out:
#           Home Score           Away  Year
# 0       France   4–1         Mexico  1930
# 1      Uruguay   4–2      Argentina  1930
# 2      Uruguay   6–1     Yugoslavia  1930
# 3    Argentina   6–1  United States  1930
# 4     Paraguay   1–0        Belgium  1930
# ..         ...   ...            ...   ...
# 923      Japan   0–1     Costa Rica  2022
# 924      Spain   1–1        Germany  2022
# 925      Japan   2–1          Spain  2022
# 926    Morocco   0–0        Croatia  2022
# 927  Argentina  3–3          France  2022
#
# [928 rows x 4 columns]

# %%
df_all_matches.iloc[49]
# Out:
# Home      Sweden
# Score        w/o
# Away     Austria
# Year        1938
# Name: 49, dtype: object

# %%
df_all_matches.drop(index=49, inplace=True)
df_all_matches.iloc[49]
# Out:
# Home               Hungary
# Score                  6–0
# Away     Dutch East Indies
# Year                  1938
# Name: 50, dtype: object

# %%
df_all_matches.reset_index(inplace=True, drop=True)
df_all_matches.iloc[49]
# Out:
# Home               Hungary
# Score                  6–0
# Away     Dutch East Indies
# Year                  1938
# Name: 49, dtype: object

# %%
df_all_matches["Score"] = df_all_matches["Score"].str.replace("[^\d-]", "", regex=True)
df_all_matches.iloc[[494, 558, 563, 566]]
# Out:
#             Home Score      Away  Year
# 494       France    10  Paraguay  1998
# 558       Sweden    12   Senegal  2002
# 563  South Korea    21     Italy  2002
# 566      Senegal    01    Turkey  2002

# %%
# Definir un diccionario con las correcciones necesarias
correcciones = {
    494: "1-0",  # France 1-0 Paraguay
    558: "1-2",  # Sweden 1-2 Senegal
    563: "2-1",  # South Korea 2-1 Italy
    566: "0-1",  # Senegal 0-1 Turkey
}

# Aplicar las correcciones a las filas correspondientes
for index, score in correcciones.items():
    df_all_matches.at[index, "Score"] = score

# Verificar las correcciones
df_all_matches.iloc[[494, 558, 563, 566]]
# Out:
#             Home Score      Away  Year
# 494       France   1-0  Paraguay  1998
# 558       Sweden   1-2   Senegal  2002
# 563  South Korea   2-1     Italy  2002
# 566      Senegal   0-1    Turkey  2002

# %%
df_all_matches[df_all_matches['Score'].str.len() > 0]
# Out:
#           Home Score           Away  Year
# 0       France    41         Mexico  1930
# 1      Uruguay    42      Argentina  1930
# 2      Uruguay    61     Yugoslavia  1930
# 3    Argentina    61  United States  1930
# 4     Paraguay    10        Belgium  1930
# ..         ...   ...            ...   ...
# 922      Japan    01     Costa Rica  2022
# 923      Spain    11        Germany  2022
# 924      Japan    21          Spain  2022
# 925    Morocco    00        Croatia  2022
# 926  Argentina    33         France  2022
#
# [927 rows x 4 columns]

# %%
import re

# Función para validar y corregir el formato de score
def validar_formato_score(score):
    # Verifica si el score tiene el formato correcto
    if re.match(r'^\d-\d$', score):
        return score
    # Verifica si el score tiene un formato sin guión y lo corrige
    elif re.match(r'^\d{2}$', score):
        return f"{score[0]}-{score[1]}"
    else:
        return score  # Devolver tal cual si no corresponde a ninguno de los patrones anteriores

# Aplicar la función a la columna Score
df_all_matches["Score"] = df_all_matches["Score"].apply(validar_formato_score)

# Verificar los cambios
df_all_matches.head(10)
# Out:
#             Home Score           Away  Year
# 0         France   4-1         Mexico  1930
# 1        Uruguay   4-2      Argentina  1930
# 2        Uruguay   6-1     Yugoslavia  1930
# 3      Argentina   6-1  United States  1930
# 4       Paraguay   1-0        Belgium  1930
# 5  United States   3-0        Belgium  1930
# 6        Uruguay   4-0        Romania  1930
# 7        Uruguay   1-0           Peru  1930
# 8  United States   3-0       Paraguay  1930
# 9         Brazil   4-0        Bolivia  1930

# %%
df_all_matches[df_all_matches['Score'].str.len() > 3]
# Out:
# Empty DataFrame
# Columns: [Home, Score, Away, Year]
# Index: []

# %%
#Buscar espacios en blanco al inicio o al final en las columnas "Home"
df_all_matches[df_all_matches["Home"].str.contains(r'^\s|\s$')]
# Out:
# Empty DataFrame
# Columns: [Home, Score, Away, Year]
# Index: []

# %%
# Buscar espacios en blanco al inicio o al final en las columnas "Away"
df_all_matches[df_all_matches["Away"].str.contains(r'^\s|\s$')]
# Out:
# Empty DataFrame
# Columns: [Home, Score, Away, Year]
# Index: []

# %%
df_all_matches[["HomeGoals", "AwayGoals"]] = df_all_matches["Score"].str.split("-", expand=True)
df_all_matches.drop("Score", axis=1, inplace=True)
df_all_matches.head()
# Out:
#         Home           Away  Year HomeGoals AwayGoals
# 0     France         Mexico  1930         4         1
# 1    Uruguay      Argentina  1930         4         2
# 2    Uruguay     Yugoslavia  1930         6         1
# 3  Argentina  United States  1930         6         1
# 4   Paraguay        Belgium  1930         1         0

# %%
df_all_matches.rename(columns={"Home": "HomeTeam", "Away": "AwayTeam"}, inplace=True)
df_all_matches.head()
# Out:
#     HomeTeam       AwayTeam  Year HomeGoals AwayGoals
# 0     France         Mexico  1930         4         1
# 1    Uruguay      Argentina  1930         4         2
# 2    Uruguay     Yugoslavia  1930         6         1
# 3  Argentina  United States  1930         6         1
# 4   Paraguay        Belgium  1930         1         0

# %%
df_all_matches.dtypes
# Out:
# HomeTeam     object
# AwayTeam     object
# Year          int64
# HomeGoals    object
# AwayGoals    object
# dtype: object

# %%
# Filtrar valores faltantes (NaN) o inválidos (no numéricos) en las columnas 'HomeGoals'
df_all_matches[df_all_matches['HomeGoals'].isna() | ~df_all_matches['HomeGoals'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [HomeTeam, AwayTeam, Year, HomeGoals, AwayGoals]
# Index: []

# %%
# Filtrar valores faltantes (NaN) o inválidos (no numéricos) en las columnas'AwayGoals'
df_all_matches[df_all_matches['AwayGoals'].isna() | df_all_matches['AwayGoals'].apply(lambda x: not str(x).isnumeric() if x is not None else False)]
# Out:
#     HomeTeam     AwayTeam  Year HomeGoals AwayGoals
# 347  Hungary  El Salvador  1982       101      None

# %%
# Identificar el registro específico usando las columnas 'HomeTeam', 'AwayTeam' y 'Year'
df_all_matches.loc[(df_all_matches['HomeTeam'] == 'Hungary') &
                   (df_all_matches['AwayTeam'] == 'El Salvador') &
                   (df_all_matches['Year'] == 1982), ['HomeGoals', 'AwayGoals']] = [10, 1]
# Verificar la modificación
df_all_matches.loc[347]
# Out:
# HomeTeam         Hungary
# AwayTeam     El Salvador
# Year                1982
# HomeGoals             10
# AwayGoals              1
# Name: 347, dtype: object

# %%
df_all_matches[['HomeGoals', 'AwayGoals']] = df_all_matches[['HomeGoals', 'AwayGoals']].astype(int)
df_all_matches.dtypes
# Out:
# HomeTeam     object
# AwayTeam     object
# Year          int64
# HomeGoals     int64
# AwayGoals     int64
# dtype: object

# %%
df_all_matches["TotalGoals"] = df_all_matches["HomeGoals"] + df_all_matches["AwayGoals"]
df_all_matches.head()
# Out:
#     HomeTeam       AwayTeam  Year  HomeGoals  AwayGoals  TotalGoals
# 0     France         Mexico  1930          4          1           5
# 1    Uruguay      Argentina  1930          4          2           6
# 2    Uruguay     Yugoslavia  1930          6          1           7
# 3  Argentina  United States  1930          6          1           7
# 4   Paraguay        Belgium  1930          1          0           1

# %%
df_all_matches.to_csv("clean_all_fifa_worldcup_matches.csv", index=False)
df_fifa_mundiales_fix.to_csv("clean_fifa_mundiales_data_fix.csv", index=False)

# %%
# Asegurarse de que los años estén ordenados cronológicamente
sorted_years = sorted(years)

# Imprimir el número de registros para cada año en orden cronológico
for year in sorted_years:
    print(year, len(df_all_matches[df_all_matches["Year"] == year]))
# Out:
# 1930 17
# 1934 17
# 1938 18
# 1950 22
# 1954 26
# 1958 35
# 1962 32
# 1966 32
# 1970 32
# 1974 38
# 1978 38
# 1982 52
# 1986 52
# 1990 16
# 1994 52
# 1998 64
# 2002 64
# 2006 64
# 2010 64
# 2014 64
# 2018 64
# 2022 64

# %% [markdown]
# Ya has limpiado los datos, ahora falta la prediccion
#
# url = https://www.youtube.com/watch?v=EuZ4gwNNYwg
#
# timestamp: 02:15:42

# %%
from scipy.stats import poisson

# %%
# !ls
# Out:
# all_world_cup_matches.csv	     fifa_mundiales_data_fix.csv
# clean_all_fifa_worldcup_matches.csv  google-chrome-stable_current_amd64.deb
# clean_fifa_mundiales_data_fix.csv    google-chrome-stable_current_amd64.deb.1
# dict_grupos			     sample_data
# fifa_mundiales_data.csv

# %%
dict_grupos = pickle.load(open('dict_grupos', 'rb'))
df_fifa_mundiales_fix = pd.read_csv('clean_fifa_mundiales_data_fix.csv')
df_all_matches = pd.read_csv('clean_all_fifa_worldcup_matches.csv')

# %%
df_fifa_mundiales_fix
# Out:
#                  Home      Score              Away  Year
# 0              Mexico    Match 1                A2  2026
# 1                  A3    Match 2                A4  2026
# 2                  A4   Match 25                A2  2026
# 3              Mexico   Match 28                A3  2026
# 4                  A4   Match 53            Mexico  2026
# ..                ...        ...               ...   ...
# 99    Winner Match 95  Match 100   Winner Match 96  2026
# 100   Winner Match 97  Match 101   Winner Match 98  2026
# 101   Winner Match 99  Match 102  Winner Match 100  2026
# 102   Loser Match 101  Match 103   Loser Match 102  2026
# 103  Winner Match 101  Match 104  Winner Match 102  2026
#
# [104 rows x 4 columns]

# %%
dict_grupos = pickle.load(open('dict_grupos','rb'))

# %% [markdown]
# # Calcular la fuerza por equipos

# %%
df_all_matches.tail()
# Out:
#       HomeTeam    AwayTeam  Year  HomeGoals  AwayGoals  TotalGoals
# 922      Japan  Costa Rica  2022          0          1           1
# 923      Spain     Germany  2022          1          1           2
# 924      Japan       Spain  2022          2          1           3
# 925    Morocco     Croatia  2022          0          0           0
# 926  Argentina      France  2022          3          3           6

# %%
# Dividir el dataframe en df_home y df_away
df_home = df_all_matches[['HomeTeam', 'HomeGoals', 'AwayGoals']]
df_away = df_all_matches[['AwayTeam', 'AwayGoals', 'HomeGoals']]

# %%
df_home.rename(columns={'HomeTeam': 'Team', 'HomeGoals': 'GoalsScored', 'AwayGoals': 'GoalsConceded'}, inplace=True)
df_away.rename(columns={'AwayTeam': 'Team', 'AwayGoals': 'GoalsScored', 'HomeGoals': 'GoalsConceded'}, inplace=True)

# %%
df_away
# Out:
#               Team  GoalsScored  GoalsConceded
# 0           Mexico            1              4
# 1        Argentina            2              4
# 2       Yugoslavia            1              6
# 3    United States            1              6
# 4          Belgium            0              1
# ..             ...          ...            ...
# 922     Costa Rica            1              0
# 923        Germany            1              1
# 924          Spain            1              2
# 925        Croatia            0              0
# 926         France            3              3
#
# [927 rows x 3 columns]

# %%
df_team_strenght = pd.concat([df_home, df_away], ignore_index=True).groupby('Team').mean()
df_team_strenght
# Out:
#               GoalsScored  GoalsConceded
# Team
# Algeria          1.000000       1.461538
# Angola           0.333333       0.666667
# Argentina        1.752941       1.164706
# Australia        0.850000       1.850000
# Austria          1.576923       1.692308
# ...                   ...            ...
# Uruguay          1.553571       1.303571
# Wales            0.625000       1.250000
# West Germany     2.050847       1.254237
# Yugoslavia       1.551724       1.275862
# Zaire            0.000000       4.666667
#
# [85 rows x 2 columns]

# %%
# agregar una columna que cuente la cantidad de partidos jugados por cada equipo
df_team_strenght['MatchesPlayed'] = pd.concat([df_home, df_away], ignore_index=True).groupby('Team').size()
df_team_strenght
# Out:
#               GoalsScored  GoalsConceded  MatchesPlayed
# Team
# Algeria          1.000000       1.461538             13
# Angola           0.333333       0.666667              3
# Argentina        1.752941       1.164706             85
# Australia        0.850000       1.850000             20
# Austria          1.576923       1.692308             26
# ...                   ...            ...            ...
# Uruguay          1.553571       1.303571             56
# Wales            0.625000       1.250000              8
# West Germany     2.050847       1.254237             59
# Yugoslavia       1.551724       1.275862             29
# Zaire            0.000000       4.666667              3
#
# [85 rows x 3 columns]

# %%
def predict_points(home_away):
    home, away = home_away

    # Verificación de que ambos equipos estén en la lista
    if home not in df_team_strenght.index:
        raise ValueError(f"El equipo '{home}' no está en la lista de equipos. Por favor, elige un equipo válido.")
    if away not in df_team_strenght.index:
        raise ValueError(f"El equipo '{away}' no está en la lista de equipos. Por favor, elige un equipo válido.")

    lamb_home = df_team_strenght.at[home, "GoalsScored"] * df_team_strenght.at[away, "GoalsConceded"]
    lamb_away = df_team_strenght.at[away, "GoalsScored"] * df_team_strenght.at[home, "GoalsConceded"]
    prob_home, prob_away, prob_draw = 0, 0, 0

    for x in range(0, 11):
        for y in range(0, 11):
            p = poisson.pmf(x, lamb_home) * poisson.pmf(y, lamb_away)
            if x == y:
                prob_draw += p
            elif x > y:
                prob_home += p
            else:
                prob_away += p

    points_home = 3 * prob_home + prob_draw
    points_away = 3 * prob_away + prob_draw
    return (points_home, points_away)

# %%
predict_points(["Qatar", 'Mexico'])
# Out:
# (0.35118599740960965, 2.5009767607785265)

# %%
print(df_fix)
# Out:
#             Home         Score          Away  Year
# 0         Qatar            0–2       Ecuador  2022
# 1       Senegal            0–2   Netherlands  2022
# 2         Qatar            1–3       Senegal  2022
# 3   Netherlands            1–1       Ecuador  2022
# 4       Ecuador            1–2       Senegal  2022
# ..           ...           ...           ...   ...
# 59      England            1–2        France  2022
# 60    Argentina            3–0       Croatia  2022
# 61       France            2–0       Morocco  2022
# 62      Croatia            2–1       Morocco  2022
# 63    Argentina   3–3 (a.e.t.)        France  2022
#
# [64 rows x 4 columns]

# %%
# # Crear una columna temporal con los números extraídos de la columna "Score"
# df_fix['Match_Number'] = df_fix['Score'].str.extract(r'(\d+)').astype(int)

# # Ordenar el DataFrame por la columna temporal
# df_fix = df_fix.sort_values(by='Match_Number').reset_index(drop=True)

# # Eliminar la columna temporal
# df_fix = df_fix.drop(columns=['Match_Number'])

# # Mostrar el DataFrame ordenado
# print(df_fix)

# %%
# Dividir el calendario en fase de grupos, 16vos, 8vos, 4tos, Semi y Final
df_fix_group_stage = df_fix[:48].copy()
df_fix_round16 = df_fix[48:56].copy()
df_fix_quarter_finals = df_fix[56:60].copy()
df_fix_semi_finals = df_fix[60:62].copy()
df_fix_final = df_fix[62:].copy()
# df_fix_final = df_fix[103:104].copy()  # Asegúrate de que sea un DataFrame

# %%
df_fix_round32
# Out:
#                  Home     Score                 Away  Year
# 72  Runner-up Group A  Match 73    Runner-up Group B  2026
# 73     Winner Group E  Match 74  3rd Group A/B/C/D/F  2026
# 74     Winner Group F  Match 75    Runner-up Group C  2026
# 75     Winner Group C  Match 76    Runner-up Group F  2026
# 76     Winner Group I  Match 77  3rd Group C/D/F/G/H  2026
# 77  Runner-up Group E  Match 78    Runner-up Group I  2026
# 78     Winner Group A  Match 79  3rd Group C/E/F/H/I  2026
# 79     Winner Group L  Match 80  3rd Group E/H/I/J/K  2026
# 80     Winner Group D  Match 81  3rd Group B/E/F/I/J  2026
# 81     Winner Group G  Match 82  3rd Group A/E/H/I/J  2026
# 82  Runner-up Group K  Match 83    Runner-up Group L  2026
# 83     Winner Group H  Match 84    Runner-up Group J  2026
# 84     Winner Group B  Match 85  3rd Group E/F/G/I/J  2026
# 85     Winner Group J  Match 86    Runner-up Group H  2026
# 86     Winner Group K  Match 87  3rd Group D/E/I/J/L  2026
# ...

# %%
# !ls
# Out:
# all_world_cup_matches.csv	     fifa_mundiales_data_fix.csv
# clean_all_fifa_worldcup_matches.csv  google-chrome-stable_current_amd64.deb
# clean_fifa_mundiales_data_fix.csv    google-chrome-stable_current_amd64.deb.1
# dict_grupos			     sample_data
# fifa_mundiales_data.csv

# %%
for group in dict_grupos:
    print(dict_grupos[group]["Team"].values)
# Out:
# ['Qatar (H)' 'Ecuador' 'Senegal' 'Netherlands']
# ['England' 'Iran' 'United States' 'Wales']
# ['Argentina' 'Saudi Arabia' 'Mexico' 'Poland']
# ['France' 'Australia' 'Denmark' 'Tunisia']
# ['Spain' 'Costa Rica' 'Germany' 'Japan']
# ['Belgium' 'Canada' 'Morocco' 'Croatia']
# ['Brazil' 'Serbia' 'Switzerland' 'Cameroon']
# ['Portugal' 'Ghana' 'Uruguay' 'South Korea']

# %%
dict_grupos.keys()
# Out:
# dict_keys(['Grupo A', 'Grupo B', 'Grupo C', 'Grupo D', 'Grupo E', 'Grupo F', 'Grupo G', 'Grupo H'])

# %%
# Asegúrate de que dict_grupos tenga las columnas adecuadas
for group in dict_grupos.keys():
    teams_in_group = dict_grupos[group]["Team"].values
    df_fix_group_6 = df_fix_group_stage[df_fix_group_stage["Home"].isin(teams_in_group)]

    # Iterar sobre los partidos en el grupo
    for index, row in df_fix_group_6.iterrows():
        home, away = row["home"], row["away"]
        points_home, points_away = predict_points([home, away])

        # Actualizar los puntos en dict_grupos
        dict_grupos[group].loc[dict_grupos[group]["Team"] == home, "Pts"] += points_home
        dict_grupos[group].loc[dict_grupos[group]["Team"] == away, "Pts"] += points_away

    # Ordenar los equipos del grupo por puntos y actualizar dict_grupos
    dict_grupos[group] = dict_grupos[group].sort_values("Pts", ascending=False).reset_index(drop=True)
    dict_grupos[group] = dict_grupos[group][["Team", "Pts"]]
    dict_grupos[group] = dict_grupos[group].round(0)

# %%
dict_grupos["Grupo A"]
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1    Qatar (H)    0  0  0  0   0   0   0    0
# 1    2      Ecuador    0  0  0  0   0   0   0    0
# 2    3      Senegal    0  0  0  0   0   0   0    0
# 3    4  Netherlands    0  0  0  0   0   0   0    0

# %%
# Asegúrate de que dict_grupos tenga la columna "Pts" inicializada
for group in dict_grupos.keys():
    dict_grupos[group]["Pts"] = 0

# Iterar sobre cada grupo y actualizar los puntos
for group in dict_grupos.keys():
    teams_in_group = dict_grupos[group]["Team"].values
    df_fix_group_6 = df_fix_group_stage[df_fix_group_stage["Home"].isin(teams_in_group)]

    # Iterar sobre los partidos en el grupo
    for index, row in df_fix_group_6.iterrows():
        home, away = row["Home"], row["Away"]
        points_home, points_away = predict_points([home, away])

        # Actualizar los puntos en dict_grupos
        dict_grupos[group].loc[dict_grupos[group]["Team"] == home, "Pts"] += points_home
        dict_grupos[group].loc[dict_grupos[group]["Team"] == away, "Pts"] += points_away

    # Ordenar los equipos del grupo por puntos y actualizar dict_grupos
    dict_grupos[group] = dict_grupos[group].sort_values("Pts", ascending=False).reset_index(drop=True)
    dict_grupos[group] = dict_grupos[group][["Team", "Pts"]].round(0)

# Visualiza un grupo, por ejemplo, el Grupo A
print(dict_grupos["Grupo A"])
# Out:
#           Team  Pts
# 0    Qatar (H)    0
# 1      Ecuador    0
# 2      Senegal    0
# 3  Netherlands    0

# %% [markdown]
# Ya casi terminas, revisa porque las predicciones no funcionan de forma correcta.
#
# URL: https://www.youtube.com/watch?v=EuZ4gwNNYwg
#
# timestamp: 03:01:00
